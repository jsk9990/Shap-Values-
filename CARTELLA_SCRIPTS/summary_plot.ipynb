# %%
# !pip install shap

# %%
import xgboost

import shap

# train xgboost model on diabetes data:
X, y = shap.datasets.diabetes()
bst = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(X, label=y), 100)

# explain the model's prediction using SHAP values
shap_values = shap.TreeExplainer(bst).shap_values(X)

type(shap_values)

#    Age (età): L'età del paziente.
#    Sex (sesso): Il sesso del paziente (solitamente codificato come maschio o femmina).
#    BMI (Body Mass Index): Indice di massa corporea, calcolato come peso in chilogrammi diviso per il quadrato dell'altezza in metri (kg/m^2).
#    BP (Blood Pressure): La pressione sanguigna del paziente.
#    S1-S6: Queste sono misurazioni di diverse caratteristiche del sangue, che possono includere livelli di glucosio, livelli di insulina e altri parametri correlati al metabolismo.
#   Y: Questo potrebbe rappresentare la variabile di output, ovvero il risultato o la misurazione del diabete.
# Out:
# numpy.ndarray

# %%
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
feat_names = list(X.columns)
shap.plots.violin(
    shap_values, features=X, feature_names=feat_names, plot_type="layered_violin"
)
